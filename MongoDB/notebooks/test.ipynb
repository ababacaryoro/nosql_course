# %%
# !pip install pymongo dotenv
# Out:
# Requirement already satisfied: pymongo in /opt/conda/lib/python3.11/site-packages (4.12.1)
# Collecting dotenv
#   Downloading dotenv-0.9.9-py2.py3-none-any.whl.metadata (279 bytes)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /opt/conda/lib/python3.11/site-packages (from pymongo) (2.7.0)
# Collecting python-dotenv (from dotenv)
#   Downloading python_dotenv-1.1.0-py3-none-any.whl.metadata (24 kB)
# Downloading dotenv-0.9.9-py2.py3-none-any.whl (1.9 kB)
# Downloading python_dotenv-1.1.0-py3-none-any.whl (20 kB)
# Installing collected packages: python-dotenv, dotenv
# Successfully installed dotenv-0.9.9 python-dotenv-1.1.0

# %%
# !pip install pymongo dotenv
from pymongo import MongoClient
import os
from dotenv import load_dotenv, find_dotenv

load_dotenv(find_dotenv())

usr = "root" # os.environ.get("MONGO_INITDB_ROOT_USERNAME")
pwd = "pwd" # os.environ.get("MONGO_INITDB_ROOT_PASSWORD")
url = f"mongodb://{usr}:{pwd}@mongo:27017"
client = MongoClient(url)

# %%
db = client["school"]
students = db["students"]

# %%
# 🟢 CREATE
new_student = {
    "name": "Alice",
    "age": 22,
    "class": "Math",
    "grades": [15, 17, 19]
}
insert_result = students.insert_one(new_student)
print(f"Inserted student with _id: {insert_result.inserted_id}")
# Out:
# Inserted student with _id: 681930d067417258e1f32f27

# %%
# 🔵 READ
# Get all students
all_students = students.find()
for student in all_students:
    print(student)

# Find one student
student = students.find_one({"name": "Alice"})
print("Found:", student)
# Out:
# {'_id': ObjectId('681930ad67417258e1f32f25'), 'name': 'Alice', 'age': 22, 'class': 'Math', 'grades': [15, 17, 19]}
# {'_id': ObjectId('681930d067417258e1f32f27'), 'name': 'Alice', 'age': 22, 'class': 'Math', 'grades': [15, 17, 19]}
# Found: {'_id': ObjectId('681930ad67417258e1f32f25'), 'name': 'Alice', 'age': 22, 'class': 'Math', 'grades': [15, 17, 19]}

# %%
# 🟠 UPDATE
students.update_one(
    {"name": "Alice"},
    {"$set": {"age": 23}}
)

# Verify update
updated_student = students.find_one({"name": "Alice"})
print("Updated:", updated_student)
# Out:
# Updated: {'_id': ObjectId('681930ad67417258e1f32f25'), 'name': 'Alice', 'age': 23, 'class': 'Math', 'grades': [15, 17, 19]}

# %%
# 🔴 DELETE
students.delete_one({"name": "Alice"})
print("Deleted Alice")
# Out:
# Deleted Alice

# %%
# Close the connection
client.close()
